# %%
from numpy import ones,vstack
from numpy.linalg import lstsq
import pandas as pd
import numpy as np
np.warnings.filterwarnings('ignore')

# Low GP Penalty, Year 2 Year Avgs,

# %%
def calculatingFormula(x, x1):
    points = [(x,MAX_RATING),(x1,MIN_RATING)]  
    x_coords, y_coords = zip(*points)
    A = vstack([x_coords,ones(len(x_coords))]).T
    m, c = lstsq(A, y_coords)[0]
    return [m, c]

def pointSlopeValue(x, m, b):
    y = (m)*(x) + (b)
    return y

def statPerGame(columnHeader, currentCol):
    # Get per game metric
    tempArray = []
    for index, row in df.iterrows():
        tempArray.append(row[currentCol] / row.G)

    # Add per game metric to data frame
    df[columnHeader] = tempArray

    # Calculate rating for stat
    statRating(columnHeader)

def statRating(columnHeader):
    # Sort data for given stat
    sortedFor = df.sort_values(by=[columnHeader], ascending=False)

    # Calculate slope equation values
    formulaVals = calculatingFormula(sortedFor[columnHeader].iloc[0], sortedFor[columnHeader].iloc[len(df.index) - 1])

    # Get rating for each player using equation
    rating = []
    for index, row in df.iterrows():
        rating.append(int(pointSlopeValue(row[columnHeader], formulaVals[0], formulaVals[1])))

    # Add ratings to data frame
    df[((columnHeader + 'Rating'))] = rating
    
def scaledRating(columnHeader):
    # Sort data for given stat
    sortedFor = df.sort_values(by=[columnHeader], ascending=False)

    # Calculate slope equation values
    formulaVals = calculatingFormula(sortedFor[columnHeader].iloc[0], sortedFor[columnHeader].iloc[len(df.index) - 1])

    # Get rating for each player using equation
    rating = []
    for index, row in df.iterrows():
        rating.append(int(pointSlopeValue(row[columnHeader], formulaVals[0], formulaVals[1])))

    # Add ratings to data frame
    df[(("scaled" + columnHeader))] = rating

# %%
def calculateForYears(df, fileName):

    # Setting Stats and Per Games
    perGameHeaders = ["DRBPG", "DRB", "BPG", "BLK", "SPG", "STL", "PPG", "PTS", "APG", "AST", "ORBPG", "ORB"]
    headers = ["STLpc", "BLKpc", "DWS", "DBPM", "ASTpc", "OWS", "TSpc", "PER", "OBPM", "PTS", "VORP", "USGpc", "TPAr"]

    for x in range(0, len(perGameHeaders), 2):
        statPerGame(perGameHeaders[x], perGameHeaders[x + 1])

    for x in headers:
        statRating(x)

    # Get Defensive Ratings
    defensiveRating = []
    for index, row in df.iterrows():
        defensiveRate = int(((row.BPGRating * defense["blkWeight"]) + (row.SPGRating * defense["stlWeight"]) + (row.DWSRating * defense["dwsWeight"]) + (row.DBPMRating * defense["dbpmWeight"]) + (row.STLpcRating * defense["stlWeight"]) + (row.BLKpcRating * defense["blkpcWight"]) + (row.DRBPGRating * defense["drbWeight"])) / defSum)
        defensiveRating.append(defensiveRate)

    df['defensiveRating'] = defensiveRating

    # Get Offensive Ratings
    offensiveRating = []
    for index, row in df.iterrows():
        offensiveRate = int(((row.PPGRating * offense["ppgWeight"]) + (row.APGRating * offense["astWeight"]) + (row.TSpcRating * offense["tspcWeight"]) + (row.OWSRating * offense["owsWeight"]) + (row.PERRating * offense["perWeight"]) + (row.OBPMRating * offense["obpmWeight"]) + (row.ASTpcRating * offense["astpcWeight"]) + (row.PTSRating * offense["ptsWeight"]) + (row.USGpcRating * offense["usgpcWeight"])) / offSum)
        offensiveRating.append(offensiveRate)

    df['offensiveRating'] = offensiveRating

    # Calculate Player Ratings
    scaledRating("defensiveRating")
    scaledRating("offensiveRating")

    playerRating = []
    for index, row in df.iterrows():
        playerRate = int(((row.offensiveRating * 1.15) + (row.defensiveRating * .85)))
        playerRating.append(playerRate)

    df['playerRating'] = playerRating

    # Export To CSV
    sortedBy = df.sort_values(by=["playerRating"], ascending=False)

    sortedBy.to_csv("ratings/withRatings_" + fileName)

# %%
# Off
offense = {
    "orbWeight": 1,
    "astWeight": 1,
    "ppgWeight": 2.5,
    "astpcWeight": .5,
    "owsWeight": 2,
    "tspcWeight": .5,
    "perWeight": 3.5,
    "obpmWeight": 4.5,
    "ptsWeight": 2, 
    "usgpcWeight": .5
}


# Def
defense = {
    "drbWeight": 1,
    "stlWeight": 1,
    "blkWeight": 1,
    "stlpcWeight": .5,
    "blkpcWight": .5,
    "dwsWeight": 3,
    "dbpmWeight": 3.5,
}

offSum = 0
defSum = 0
for x in offense:
    offSum += offense[x]
print("Offensive Weighted Sum: " + str(offSum))
for x in defense:
    defSum += defense[x]
print("Defensive Weighted Sum: " + str(defSum))

MAX_RATING = 97
MIN_RATING = 68
# Out:
# Offensive Weighted Sum: 18.0
# Defensive Weighted Sum: 10.5

# %%
years = list(range(2004, 2023))

for year in years:
    fileName = "stats_{}.csv".format(year)

    df = pd.read_csv("csvStats/" + fileName)
    df.dropna(inplace=True) # Drops NaN
    df.columns=df.columns.str.replace('%', 'pc') # Replace % symbols w/ pc
    df.columns=df.columns.str.replace('3', 'T') # Replace 3 with T

    # Drop players who played less than 20 games
    for index, row in df.iterrows():
        if row.G < 20:
            print(row.Player + " dropped")
            df.drop(index, inplace=True)

    # Calculate Rating For Each Year
    calculateForYears(df, fileName)
# Out:
# Troy Bell dropped
# Curtis Borchardt dropped
# Jamison Brewer dropped
# Matt Carroll dropped
# Maurice Carter dropped
# Mateen Cleaves dropped
# Hubert Davis dropped
# Josh Davis dropped
# Derrick Dial dropped
# Bryce Drew dropped
# Desmond Ferguson dropped
# Anthony Goldwire dropped
# Adrian Griffin dropped
# Shane Heal dropped
# James Jones dropped
# Raef LaFrentz dropped
# Dan Langhi dropped
# Rusty LaRue dropped
# Randy Livingston dropped
# Darrick Martin dropped
# Jamal Mashburn dropped
# Tracy Murray dropped
# Glen Rice dropped
# Paul Shirley dropped
# Jeff Trepagnier dropped
# Ime Udoka dropped
# Chris Whitney dropped
# Wang Zhizhi dropped
# Cory Alexander dropped
# Jonathan Bender dropped
# Michael Bradley dropped
# Jamison Brewer dropped
# Damone Brown dropped
# Kedrick Brown dropped
# Mateen Cleaves dropped
# Derrick Coleman dropped
# Omar Cook dropped
# Kaniel Dickens dropped
# Ndudi Ebi dropped
# Luis Flores dropped
# Tremaine Fowlkes dropped
# Alex Garcia dropped
# Devean George dropped
# Kendall Gill dropped
# Dion Glover dropped
# Marcus Haislip dropped
# Luke Jackson dropped
# Horace Jenkins dropped
# Mark Jones dropped
# Kerry Kittles dropped
# Voshon Lenard dropped
# Randy Livingston dropped
# Darrick Martin dropped
# Ron Mercer dropped
# Mamadou N'Diaye dropped
# Smush Parker dropped
# Glenn Robinson dropped
# Ansu Sesay dropped
# Tamar Slay dropped
# Awvee Storey dropped
# Rod Strickland dropped
# Yuta Tabuse dropped
# Dajuan Wagner dropped
# Charlie Ward dropped
# Scott Williams dropped
# Metta World Peace dropped
# Dorell Wright dropped
# Andre Barrett dropped
# Eddie Basden dropped
# Will Bynum dropped
# Doug Christie dropped
# Josh Davis dropped
# Dan Dickau dropped
# Noel Felix dropped
# Gerald Fitch dropped
# Marcus Fizer dropped
# Reece Gaines dropped
# Willie Green dropped
# Anthony Grundy dropped
# Anfernee Hardaway dropped
# Amir Johnson dropped
# Arvydas Macijauskas dropped
# Aaron McKie dropped
# Anthony Roberson dropped
# Melvin Sanders dropped
# Amar'e Stoudemire dropped
# Billy Thomas dropped
# Dijon Thompson dropped
# Nikoloz Tskitishvili dropped
# Ime Udoka dropped
# Von Wafer dropped
# Alvin Williams dropped
# Bracey Wright dropped
# Alan Anderson dropped
# Will Blalock dropped
# Doug Christie dropped
# Desmon Farmer dropped
# Danny Fortson dropped
# Matt Freije dropped
# Stephen Graham dropped
# Eddie Griffin dropped
# Robert Hite dropped
# Luke Jackson dropped
# Amir Johnson dropped
# Jumaine Jones dropped
# Yaroslav Korolev dropped
# Kyle Lowry dropped
# Sean Marks dropped
# Kenyon Martin dropped
# Ivan McFarlin dropped
# Stanislav Medvedenko dropped
# Ira Newble dropped
# Eric Piatkowski dropped
# Kevinn Pinkney dropped
# Roger Powell dropped
# Peja Stojaković dropped
# Dijon Thompson dropped
# Marcus Vinicius dropped
# James White dropped
# Alvin Williams dropped
# Bracey Wright dropped
# Blake Ahearn dropped
# Morris Almond dropped
# Gilbert Arenas dropped
# Andre Barrett dropped
# P.J. Brown dropped
# Guillermo Díaz dropped
# Richie Frahm dropped
# Steve Francis dropped
# Thomas Gardner dropped
# Eddie Gill dropped
# Taurean Green dropped
# Anfernee Hardaway dropped
# Mike Harris dropped
# Nenê dropped
# Troy Hudson dropped
# Luke Jackson dropped
# DerMarr Johnson dropped
# Linton Johnson dropped
# Coby Karl dropped
# Viktor Khryapa dropped
# Tarence Kinsey dropped
# Sean Marks dropped
# Darrick Martin dropped
# Eric Piatkowski dropped
# Kasib Powell dropped
# Gabe Pruitt dropped
# Ramon Sessions dropped
# Billy Thomas dropped
# Alando Tucker dropped
# Marcus Vinicius dropped
# Darius Washington dropped
# Mike Wilks dropped
# Blake Ahearn dropped
# Gilbert Arenas dropped
# Corey Brewer dropped
# Dee Brown dropped
# Joe Crawford dropped
# Austin Croshere dropped
# Mike Dunleavy dropped
# Desmon Farmer dropped
# Thomas Gardner dropped
# Malik Hairston dropped
# Dontell Jefferson dropped
# Cuttino Mobley dropped
# DeMarcus Nelson dropped
# Demetris Nichols dropped
# Shavlik Randolph dropped
# Jeremy Richardson dropped
# Cheikh Samb dropped
# Walter Sharpe dropped
# Jerry Stackhouse dropped
# Stromile Swift dropped
# Anthony Tolliver dropped
# Sonny Weems dropped
# Marcus Williams dropped
# Shawne Williams dropped
# Joe Alexander dropped
# Kelenna Azubuike dropped
# Renaldo Balkman dropped
# Tony Battie dropped
# Raja Bell dropped
# Will Conroy dropped
# Brian Cook dropped
# Travis Diener dropped
# Jeff Foster dropped
# Alonzo Gee dropped
# Taylor Griffin dropped
# Marcus Haislip dropped
# Mike Harris dropped
# Lindsey Hunter dropped
# Cedric Jackson dropped
# Mike James dropped
# Coby Karl dropped
# Marcus Landry dropped
# Cartier Martin dropped
# Patty Mills dropped
# Patrick O'Bryant dropped
# Michael Redd dropped
# Tim Thomas dropped
# Alando Tucker dropped
# Roko Ukić dropped
# Kyle Weaver dropped
# Mike Wilks dropped
# Renaldo Balkman dropped
# Charlie Bell dropped
# Antonio Daniels dropped
# Patrick Ewing dropped
# Josh Howard dropped
# Lester Hudson dropped
# Othyus Jeffers dropped
# Trey Johnson dropped
# Dominique Jones dropped
# John Lucas III dropped
# Mehmet Okur dropped
# Larry Owens dropped
# Andy Rautins dropped
# Michael Redd dropped
# Jerry Stackhouse dropped
# Lance Stephenson dropped
# Pape Sy dropped
# Willie Warren dropped
# Kyle Weaver dropped
# Mario West dropped
# Morris Almond dropped
# Alan Anderson dropped
# Gilbert Arenas dropped
# Renaldo Balkman dropped
# Keith Bogans dropped
# Andrew Bogut dropped
# Earl Boykins dropped
# Craig Brackins dropped
# Derrick Byars dropped
# Wilson Chandler dropped
# Josh Davis dropped
# Justin Dentmon dropped
# Jerome Dyson dropped
# Andre Emmett dropped
# Christian Eyenga dropped
# T.J. Ford dropped
# Courtney Fortson dropped
# Jeff Foster dropped
# Eric Gordon dropped
# Justin Harper dropped
# Tyler Honeycutt dropped
# Al Horford dropped
# Dennis Horner dropped
# Lester Hudson dropped
# Larry Hughes dropped
# Damion James dropped
# Mike James dropped
# Armon Johnson dropped
# Carldell Johnson dropped
# D.J. Kennedy dropped
# Malcolm Lee dropped
# DeAndre Liggins dropped
# Cartier Martin dropped
# Eric Maynor dropped
# Brad Miller dropped
# Patty Mills dropped
# Jamario Moon dropped
# Darius Morris dropped
# Marcus Morris dropped
# Andrés Nocioni dropped
# Mehmet Okur dropped
# Daniel Orton dropped
# Larry Owens dropped
# Xavier Silas dropped
# James Singleton dropped
# DaJuan Summers dropped
# Ronny Turiaf dropped
# Edwin Ubiles dropped
# Ben Uzoh dropped
# Charlie Villanueva dropped
# Aron Baynes dropped
# Josh Childress dropped
# Will Conroy dropped
# Jared Cunningham dropped
# Keyon Dooling dropped
# Chris Douglas-Roberts dropped
# Devin Ebanks dropped
# Diante Garrett dropped
# Drew Gooden dropped
# Danny Granger dropped
# Josh Harrellson dropped
# Al Harrington dropped
# Lazar Hayward dropped
# Cory Higgins dropped
# Justin Holiday dropped
# Tyler Honeycutt dropped
# Josh Howard dropped
# Chris Johnson dropped
# Terrence Jones dropped
# Kris Joseph dropped
# Malcolm Lee dropped
# Kevin Love dropped
# Scott Machado dropped
# Corey Maggette dropped
# Quincy Miller dropped
# Troy Murphy dropped
# Mickaël Piétrus dropped
# Chris Quinn dropped
# Quentin Richardson dropped
# Brandon Roy dropped
# Brandon Rush dropped
# Samardo Samuels dropped
# Josh Selby dropped
# Tornike Shengelia dropped
# Hedo Türkoğlu dropped
# Chauncey Billups dropped
# Vander Blue dropped
# Kobe Bryant* dropped
# Dwight Buycks dropped
# Allen Crabbe dropped
# Jared Cunningham dropped
# Carrick Felix dropped
# Ben Gordon dropped
# Jorge Gutiérrez dropped
# Justin Hamilton dropped
# Manny Harris dropped
# Scotty Hopson dropped
# Stephen Jackson dropped
# Damion James dropped
# Mike James dropped
# Othyus Jeffers dropped
# John Jenkins dropped
# Darius Johnson-Odom dropped
# Ricky Ledo dropped
# Brook Lopez dropped
# Steve Nash* dropped
# James Nunnally dropped
# Quincy Pondexter dropped
# Glen Rice Jr. dropped
# Derrick Rose dropped
# Mustafa Shakur dropped
# James Southerland dropped
# Adonis Thomas dropped
# Malcolm Thomas dropped
# Casper Ware dropped
# Chris Wright dropped
# Earl Barron dropped
# Vander Blue dropped
# Jabari Brown dropped
# Shannon Brown dropped
# Dwight Buycks dropped
# Will Bynum dropped
# Will Cherry dropped
# Earl Clark dropped
# Bryce Cotton dropped
# Jared Cunningham dropped
# Toney Douglas dropped
# Chris Douglas-Roberts dropped
# Zoran Dragić dropped
# Larry Drew II dropped
# Tim Frazier dropped
# Francisco García dropped
# Paul George dropped
# Drew Gordon dropped
# Lester Hudson dropped
# Grant Jerrett dropped
# Sean Kilpatrick dropped
# Ricky Ledo dropped
# Devyn Marble dropped
# Jerel McNeal dropped
# Josh McRoberts dropped
# Quincy Miller dropped
# Jannero Pargo dropped
# Glen Rice Jr. dropped
# Jason Richardson dropped
# Russ Smith dropped
# David Stockton dropped
# Sebastian Telfair dropped
# Malcolm Thomas dropped
# Elliot Williams dropped
# Jordan Adams dropped
# Alan Anderson dropped
# Keith Appling dropped
# Jeff Ayres dropped
# Cameron Bairstow dropped
# Anthony Bennett dropped
# Elton Brand dropped
# Lorenzo Brown dropped
# Caron Butler dropped
# Bryce Dejean-Jones dropped
# Spencer Dinwiddie dropped
# Cleanthony Early dropped
# Jordan Farmar dropped
# Jimmer Fredette dropped
# Andrew Goudelock dropped
# Erick Green dropped
# Jorge Gutiérrez dropped
# Jordan Hamilton dropped
# Justin Harper dropped
# Josh Huestis dropped
# Cory Jefferson dropped
# Orlando Johnson dropped
# Chris Kaman dropped
# Michael Kidd-Gilchrist dropped
# Jodie Meeks dropped
# Luis Montero dropped
# Xavier Munford dropped
# Steve Novak dropped
# Tibor Pleiß dropped
# Russ Smith dropped
# Briante Weber dropped
# Shayne Whittington dropped
# Elliot Williams dropped
# Christian Wood dropped
# Tony Wroten dropped
# Chris Andersen dropped
# Jerryd Bayless dropped
# Joel Bolomboy dropped
# Norris Cole dropped
# Quinn Cook dropped
# Jordan Crawford dropped
# Jarell Eddie dropped
# Henry Ellenson dropped
# Michael Gbinije dropped
# Alonzo Gee dropped
# Marcus Georges-Hunt dropped
# Jonathan Gibson dropped
# Archie Goodwin dropped
# Manny Harris dropped
# Aaron Harrison dropped
# Udonis Haslem dropped
# Josh Huestis dropped
# Jarrett Jack dropped
# Demetrius Jackson dropped
# Pierre Jackson dropped
# John Jenkins dropped
# Dahntay Jones dropped
# Ryan Kelly dropped
# Nicolás Laprovíttola dropped
# Shawn Long dropped
# Chris McCullough dropped
# Elijah Millsap dropped
# Gary Neal dropped
# Johnny O'Bryant dropped
# Lamar Patterson dropped
# Adreian Payne dropped
# Gary Payton II dropped
# Alex Poythress dropped
# Ronnie Price dropped
# Tim Quarterman dropped
# Mike Scott dropped
# Wayne Selden dropped
# Tiago Splitter dropped
# Lance Stephenson dropped
# Jared Sullinger dropped
# Isaiah Taylor dropped
# Jarrod Uthoff dropped
# Greivis Vásquez dropped
# Reggie Williams dropped
# Kyle Wiltjer dropped
# Justise Winslow dropped
# Christian Wood dropped
# Kadeem Allen dropped
# Darrell Arthur dropped
# Jamel Artis dropped
# Wade Baldwin dropped
# Patrick Beverley dropped
# Jabari Bird dropped
# Antonio Blakeney dropped
# Vander Blue dropped
# Joel Bolomboy dropped
# Tony Bradley dropped
# MarShon Brooks dropped
# Lorenzo Brown dropped
# Thomas Bryant dropped
# Bruno Caboclo dropped
# Gian Clavell dropped
# Antonius Cleveland dropped
# Mike Conley dropped
# Charles Cooke dropped
# Jordan Crawford dropped
# Milton Doyle dropped
# Dante Exum dropped
# Kay Felder dropped
# Markelle Fultz dropped
# Josh Gray dropped
# Aaron Harrison dropped
# Udonis Haslem dropped
# Nigel Hayes dropped
# Isaiah Hicks dropped
# Solomon Hill dropped
# Darrun Hilliard dropped
# R.J. Hunter dropped
# Andre Ingram dropped
# Aaron Jackson dropped
# Demetrius Jackson dropped
# Brandon Jennings dropped
# Brice Johnson dropped
# Jalen Jones dropped
# Furkan Korkmaz dropped
# Damion Lee dropped
# Walt Lemon Jr. dropped
# Kawhi Leonard dropped
# Jon Leuer dropped
# Jeremy Lin dropped
# Josh Magette dropped
# Chris McCullough dropped
# Rodney McGruder dropped
# Alfonzo McKinnie dropped
# Malcolm Miller dropped
# Monte Morris dropped
# Johnathan Motley dropped
# Xavier Munford dropped
# Georges Niang dropped
# Marcus Paige dropped
# Adreian Payne dropped
# London Perrantes dropped
# Rodney Purvis dropped
# Zhou Qi dropped
# Tim Quarterman dropped
# Xavier Rathan-Mayes dropped
# Iman Shumpert dropped
# Kyle Singler dropped
# Marquis Teague dropped
# Derrick Walton dropped
# Travis Wear dropped
# Briante Weber dropped
# Andrew White dropped
# Derrick White dropped
# Okaro White dropped
# Isaiah Whitehead dropped
# Jacob Wiley dropped
# Damien Wilkins dropped
# Jamil Wilson dropped
# Jeff Withey dropped
# James Young dropped
# Quincy Acy dropped
# Deng Adel dropped
# DeVaughn Akoon-Purcell dropped
# Rawle Alkins dropped
# Kadeem Allen dropped
# Carmelo Anthony dropped
# Ron Baker dropped
# Wade Baldwin dropped
# Dillon Brooks dropped
# Tyler Cavanaugh dropped
# Bonzie Colson dropped
# Mitch Creek dropped
# Deyonta Davis dropped
# Marcus Derrickson dropped
# PJ Dozier dropped
# Henry Ellenson dropped
# Melvin Frazier dropped
# Jimmer Fredette dropped
# Markelle Fultz dropped
# Billy Garrett dropped
# Brandon Goodwin dropped
# Daniel Hamilton dropped
# Dusty Hannahs dropped
# Andrew Harrison dropped
# Udonis Haslem dropped
# John Henson dropped
# Haywood Highsmith dropped
# R.J. Hunter dropped
# Demetrius Jackson dropped
# Alize Johnson dropped
# B.J. Johnson dropped
# Jalen Jones dropped
# Jemerrio Jones dropped
# Terrence Jones dropped
# Walt Lemon Jr. dropped
# Jordan Loyd dropped
# Scott Machado dropped
# Daryl Macon dropped
# Luc Mbah a Moute dropped
# Tahjere McCall dropped
# Ben McLemore dropped
# Jodie Meeks dropped
# Malcolm Miller dropped
# Naz Mitrou-Long dropped
# Jaylen Morris dropped
# Džanan Musa dropped
# James Nunnally dropped
# Justin Patton dropped
# Theo Pinson dropped
# Cameron Reynolds dropped
# Devin Robinson dropped
# Duncan Robinson dropped
# Brandon Sampson dropped
# JaKarr Sampson dropped
# J.R. Smith dropped
# Zhaire Smith dropped
# Ray Spalding dropped
# Miloš Teodosić dropped
# Jared Terrell dropped
# Isaiah Thomas dropped
# Gary Trent Jr. dropped
# Jarred Vanderbilt dropped
# Lonnie Walker IV dropped
# Julian Washburn dropped
# Yuta Watanabe dropped
# Thomas Welsh dropped
# Alan Williams dropped
# C.J. Williams dropped
# Tyler Zeller dropped
# Kadeem Allen dropped
# Al-Farouq Aminu dropped
# Justin Anderson dropped
# Marvin Bagley III dropped
# Dragan Bender dropped
# Bol Bol dropped
# Jonah Bolden dropped
# Jarrell Brantley dropped
# Ignas Brazdeikis dropped
# Corey Brewer dropped
# Oshae Brissett dropped
# Ryan Broekhoff dropped
# Charlie Brown Jr. dropped
# Vlatko Čančar dropped
# Joe Chealey dropped
# Nic Claxton dropped
# Antonius Cleveland dropped
# Amir Coffey dropped
# Zach Collins dropped
# Stephen Curry dropped
# Melvin Frazier dropped
# Michael Frazier dropped
# Jerian Grant dropped
# Blake Griffin dropped
# Devon Hall dropped
# Dusty Hannahs dropped
# Udonis Haslem dropped
# Dewan Hernandez dropped
# Jaylen Hoard dropped
# Talen Horton-Tucker dropped
# DaQuan Jeffries dropped
# Alize Johnson dropped
# B.J. Johnson dropped
# Keldon Johnson dropped
# Mfiondu Kabengele dropped
# Louis King dropped
# John Konchar dropped
# Vic Law dropped
# Jalen Lecque dropped
# Josh Magette dropped
# Caleb Martin dropped
# Jeremiah Martin dropped
# Frank Mason III dropped
# Garrison Mathews dropped
# Luc Mbah a Moute dropped
# Jalen McDaniels dropped
# Chimezie Metu dropped
# C.J. Miles dropped
# Adam Mokoka dropped
# Johnathan Motley dropped
# Mychal Mulder dropped
# Malik Newman dropped
# Zach Norvell dropped
# Jaylen Nowell dropped
# Jusuf Nurkić dropped
# KZ Okpala dropped
# Victor Oladipo dropped
# Miye Oni dropped
# Tariq Owens dropped
# Jeremy Pargo dropped
# Cameron Payne dropped
# Shamorie Ponds dropped
# Otto Porter Jr. dropped
# Chasson Randle dropped
# Josh Reaves dropped
# Andre Roberson dropped
# Luka Šamanić dropped
# Marial Shayok dropped
# Iman Shumpert dropped
# Alen Smailagić dropped
# J.R. Smith dropped
# Zhaire Smith dropped
# Max Strus dropped
# Khyri Thomas dropped
# Lance Thomas dropped
# Sindarius Thornwell dropped
# Juan Toscano-Anderson dropped
# Evan Turner dropped
# Jarrod Uthoff dropped
# Jarred Vanderbilt dropped
# Dean Wade dropped
# Dion Waiters dropped
# Tyrone Wallace dropped
# Yuta Watanabe dropped
# Tremont Waters dropped
# Paul Watson dropped
# Quinndary Weatherspoon dropped
# Johnathan Williams dropped
# Nigel Williams-Goss dropped
# Justise Winslow dropped
# Justin Wright-Foreman dropped
# Ty-Shon Alexander dropped
# Jordan Bell dropped
# Tyler Bey dropped
# Brian Bowen dropped
# Ignas Brazdeikis dropped
# Charlie Brown Jr. dropped
# Elijah Bryant dropped
# Thomas Bryant dropped
# Bruno Caboclo dropped
# Devin Cannady dropped
# Vernon Carey Jr. dropped
# Marquese Chriss dropped
# Gabriel Deck dropped
# Dewayne Dedmon dropped
# Matthew Dellavedova dropped
# Mamadi Diakite dropped
# Spencer Dinwiddie dropped
# Kris Dunn dropped
# Henry Ellenson dropped
# Dante Exum dropped
# Cristiano Felício dropped
# Yogi Ferrell dropped
# Robert Franks dropped
# Tim Frazier dropped
# Markelle Fultz dropped
# Jared Harper dropped
# Jalen Harris dropped
# Jaylen Hoard dropped
# Rondae Hollis-Jefferson dropped
# Elijah Hughes dropped
# Ersan İlyasova dropped
# Jaren Jackson Jr. dropped
# Mike James dropped
# Alize Johnson dropped
# Louis King dropped
# Romeo Langford dropped
# Jalen Lecque dropped
# Thon Maker dropped
# Karim Mané dropped
# Jeremiah Martin dropped
# Frank Mason III dropped
# Dakota Mathias dropped
# Sean McDermott dropped
# Rodney McGruder dropped
# Darius Miller dropped
# Adam Mokoka dropped
# James Nunnally dropped
# Cameron Oliver dropped
# Jabari Parker dropped
# Justin Patton dropped
# Gary Payton II dropped
# Vincent Poirier dropped
# Jontay Porter dropped
# Jahmi'us Ramsey dropped
# Nick Richards dropped
# Andre Roberson dropped
# Jerome Robinson dropped
# Justin Robinson dropped
# Jay Scrubb dropped
# Chris Silva dropped
# Alen Smailagić dropped
# Ray Spalding dropped
# Tyrell Terry dropped
# Isaiah Thomas dropped
# Khyri Thomas dropped
# Killian Tillie dropped
# Anthony Tolliver dropped
# Axel Toupane dropped
# Rayjon Tucker dropped
# Anderson Varejão dropped
# T.J. Warren dropped
# Robert Woodard II dropped
# Justin Anderson dropped
# Paris Bass dropped
# Bol Bol dropped
# Isaac Bonga dropped
# Chaundee Brown Jr. dropped
# Vlatko Čančar dropped
# Devin Cannady dropped
# Petr Cornelie dropped
# Mamadi Diakite dropped
# Devon Dotson dropped
# Sekou Doumbouya dropped
# Jeff Dowtin dropped
# PJ Dozier dropped
# Kris Dunn dropped
# Carsen Edwards dropped
# James Ennis III dropped
# Melvin Frazier dropped
# Tim Frazier dropped
# Markelle Fultz dropped
# Marcus Garrett dropped
# Freddie Gillespie dropped
# Hassani Gravett dropped
# Kyle Guy dropped
# Jared Harper dropped
# Joe Harris dropped
# Udonis Haslem dropped
# Haywood Highsmith dropped
# Malcolm Hill dropped
# Jaylen Hoard dropped
# Wes Iwundu dropped
# Justin Jackson dropped
# Carlik Jones dropped
# Mason Jones dropped
# Georgios Kalaitzakis dropped
# Frank Kaminsky dropped
# Braxton Key dropped
# George King dropped
# Louis King dropped
# Brandon Knight dropped
# Luke Kornet dropped
# Isaiah Livers dropped
# Brook Lopez dropped
# Didi Louzada dropped
# Mac McClung dropped
# Cameron McGriff dropped
# Alfonzo McKinnie dropped
# Sam Merrill dropped
# Xavier Moon dropped
# Jaylen Morris dropped
# Markieff Morris dropped
# Mychal Mulder dropped
# Abdel Nader dropped
# RJ Nembhard Jr. dropped
# Malik Newman dropped
# Victor Oladipo dropped
# Cameron Oliver dropped
# Eugene Omoruyi dropped
# Miye Oni dropped
# Daniel Oturu dropped
# Jabari Parker dropped
# Reggie Perry dropped
# Jamorko Pickett dropped
# Theo Pinson dropped
# Yves Pons dropped
# Michael Porter Jr. dropped
# Micah Potter dropped
# Myles Powell dropped
# Trevelin Queen dropped
# Jahmi'us Ramsey dropped
# Jordan Schakel dropped
# Jay Scrubb dropped
# Wayne Selden dropped
# Collin Sexton dropped
# Marko Simonovic dropped
# Zavier Simpson dropped
# Javonte Smart dropped
# Cassius Stanley dropped
# Nik Stauskas dropped
# Brodric Thomas dropped
# Isaiah Todd dropped
# Rayjon Tucker dropped
# Tyrone Wallace dropped
# Derrick Walton dropped
# Paul Watson dropped
# Quinndary Weatherspoon dropped
# Lindell Wigginton dropped
# Patrick Williams dropped
# D.J. Wilson dropped
# Cassius Winston dropped
# Robert Woodard II dropped
# Moses Wright dropped
# Gabe York dropped

# %%
# perGameHeaders = ["DRBPG", "DRB", "BPG", "BLK", "SPG", "STL", "PPG", "PTS", "APG", "AST", "ORBPG", "ORB"]
# headers = ["STLpc", "BLKpc", "DWS", "DBPM", "ASTpc", "OWS", "TSpc", "PER", "OBPM", "PTS", "VORP", "USGpc", "TPAr"]

# for x in range(0, len(perGameHeaders), 2):
#     statPerGame(perGameHeaders[x], perGameHeaders[x + 1])

# for x in headers:
#     statRating(x)

# %%
# defensiveRating = []
# for index, row in df.iterrows():
#     defensiveRate = int(((row.BPGRating * defense["blkWeight"]) + (row.SPGRating * defense["stlWeight"]) + (row.DWSRating * defense["dwsWeight"]) + (row.DBPMRating * defense["dbpmWeight"]) + (row.STLpcRating * defense["stlWeight"]) + (row.BLKpcRating * defense["blkpcWight"]) + (row.DRBPGRating * defense["drbWeight"])) / defSum)
#     defensiveRating.append(defensiveRate)

# df['defensiveRating'] = defensiveRating

# %%
# offensiveRating = []
# for index, row in df.iterrows():
#     offensiveRate = int(((row.PPGRating * offense["ppgWeight"]) + (row.APGRating * offense["astWeight"]) + (row.TSpcRating * offense["tspcWeight"]) + (row.OWSRating * offense["owsWeight"]) + (row.PERRating * offense["perWeight"]) + (row.OBPMRating * offense["obpmWeight"]) + (row.ASTpcRating * offense["astpcWeight"]) + (row.PTSRating * offense["ptsWeight"])) / offSum)
#     offensiveRating.append(offensiveRate)

# df['offensiveRating'] = offensiveRating

# %%
# scaledRating("defensiveRating")
# scaledRating("offensiveRating")

# playerRating = []
# for index, row in df.iterrows():
#     playerRate = int(((row.offensiveRating) + (row.defensiveRating)))
#     playerRating.append(playerRate)

# df['playerRating'] = playerRating

# # scaledRating("playerRating")

# # sortedBy = df.sort_values(by=['scaledplayerRating'], ascending=False)

# %%
# sortedBy = df.sort_values(by=["playerRating"], ascending=False)

# sortedBy.to_csv("ratings/withRatings_" + fileName)

# for index, row in sortedBy.iterrows():
#     string = "{:>24} | Rating: {} | Off Rating: {} | Def Rating: {} |  Games Played: {}"
#     print(string.format(row.Player,str(row.playerRating),str(row.offensiveRating),str(row.defensiveRating),str(row.G)))

# %%
finalDataFrame = pd.DataFrame()

for year in years:
    fileName = "ratings/withRatings_stats_{}.csv".format(year)
    df = pd.read_csv(fileName)

    data = []

    for index, row in df.iterrows():
        data.append([row.Player, year, row.Pos, row.Age, row.Tm, row.scaledoffensiveRating, row.scaleddefensiveRating, row.playerRating])

    tempDataFrame = pd.DataFrame(data, columns=['PlayerName','Season', 'Position', 'Age', 'Team', 'OffensiveRating', 'DefensiveRating', 'RatingSum'])

    finalDataFrame = pd.concat([finalDataFrame, tempDataFrame])

df = finalDataFrame

scaledRating("RatingSum")

sortedBy = finalDataFrame.sort_values(by=["scaledRatingSum"], ascending=False)

sortedBy.to_csv("ratingsOverTime.csv")

# %%
for year in years:
    dataFrame = df.loc[df['Season'] == year]

    dataFrame.to_csv("finalRatings/fr_" + str(year) + ".csv")
